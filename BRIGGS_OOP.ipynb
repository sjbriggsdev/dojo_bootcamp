# %% [markdown]
# <a href="https://colab.research.google.com/github/sjbriggsdev/dojo_bootcamp/blob/main/BRIGGS_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   make_withdrawal(self, amount) - have this method decrease the user's balance by the amount specified
# *   display_user_balance(self) - have this method print the user's name and account balance to the terminal
# eg. "User: Guido van Rossum, Balance: $150

# %%
class User:
    
    def __init__(self,name,start_balance=0):
        self.name =  name
        self.balance = start_balance


    def make_withdrawal(self,amount):
        # self.balance = self.balance - amount
        self.balance -= amount
        return self
        
    def make_deposit(self,amount):
        # self.balance = self.balance + amount
        self.balance += amount
        return self

    def make_transfer(self,amount):
        # self.balance = self.balance + amount
        self.balance += amount
        return self
    def yield_interest(self): #yield interest method
        if self.balance < 0:
            pass
        else:
            self.balance = self.balance + (self.balance * self.int_rate)
            return self.balance 
    def display_user_balance(self):
        print(f"User: {self.name}, Balance: ${self.balance}")

user1 = User("Guido van Rossum",start_balance=150)
user1.name
user1.display_user_balance()
# Out:
# User: Guido van Rossum, Balance: $150

# %%
user1.make_deposit(3.50)
user1.make_deposit(450)
user1.make_deposit(100)
user1.make_withdrawal(50)

user1.display_user_balance()
# Out:
# User: Guido van Rossum, Balance: $653.5

# %%
## Make a second user, Steve, with a starting balance of 500

user2 = User("Steve", start_balance=500 )

## display balance
user2.display_user_balance()
## Deposit $50, withdraw $100 and display balance
user2.make_deposit(50)
user2.make_withdrawal(100)
user2.display_user_balance()
# Out:
# User: Steve, Balance: $500
# User: Steve, Balance: $450

# %% [markdown]
# *   BONUS: transfer_money(self, other_user, amount) - have this method decrease the user's balance by the amount and add that amount to other other_user's balance
